# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import statistics
import scipy
# %matplotlib inline

# %%
dfjan = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data Jan.csv')
dfjan.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  4.093200e+04      40932.000000            40932.000000
# mean   8.652969e+02         91.366584               42.359132
# std    1.273104e+04         58.662423                0.014163
# min    6.100000e+01          1.000000               42.303469
# 25%    3.510000e+02         42.000000               42.350406
# 50%    5.470000e+02         80.000000               42.359912
# 75%    8.780000e+02        135.000000               42.366277
# max    2.440760e+06        232.000000               42.400877
#
#        start station longitude  end station id  end station latitude  \
# count             40932.000000    40932.000000          40932.000000
# mean                -71.087721       90.063373             42.359201
# std                   0.024405       58.733981              0.014015
# min                 -71.166491        1.000000             42.303469
# 25%                 -71.104412       40.000000             42.350406
# 50%                 -71.091156       80.000000             42.359912
# 75%                 -71.067662      131.000000             42.366277
# max                 -71.006098      232.000000             42.400877
#
#        end station longitude        bikeid    birth year        gender
# count           40932.000000  40932.000000  39393.000000  40932.000000
# mean              -71.087206   1047.998046   1982.697840      1.163662
# std                 0.024361    594.272737     11.138479      0.472720
# min               -71.166491      2.000000   1929.000000      0.000000
# 25%               -71.104079    549.000000   1977.000000      1.000000
# 50%               -71.091156   1026.000000   1986.000000      1.000000
# 75%               -71.066289   1662.000000   1991.000000      1.000000
# max               -71.006098   1981.000000   2001.000000      2.000000

# %%
dffeb = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data Feb.csv')
dffeb.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  6.281700e+04      62817.000000            62817.000000
# mean   9.813870e+02         91.228139               42.359000
# std    1.554940e+04         59.368664                0.014136
# min    6.100000e+01          1.000000               42.303469
# 25%    3.580000e+02         41.000000               42.350406
# 50%    5.660000e+02         80.000000               42.359912
# 75%    9.140000e+02        135.000000               42.366277
# max    2.317626e+06        232.000000               42.400877
#
#        start station longitude  end station id  end station latitude  \
# count             62817.000000    62817.000000          62817.000000
# mean                -71.087902       90.055256             42.358370
# std                   0.024585       59.365460              0.169575
# min                 -71.166491        1.000000              0.000000
# 25%                 -71.104412       40.000000             42.350406
# 50%                 -71.091156       78.000000             42.359912
# 75%                 -71.068607      133.000000             42.366277
# max                 -71.006098      232.000000             42.400877
#
#        end station longitude        bikeid    birth year        gender
# count           62817.000000  62817.000000  59320.000000  62817.000000
# mean              -71.086144   1025.110941   1982.906305      1.158317
# std                 0.284691    596.244297     11.387816      0.502517
# min               -71.166491      1.000000   1886.000000      0.000000
# 25%               -71.104412    522.000000   1978.000000      1.000000
# 50%               -71.088220    999.000000   1987.000000      1.000000
# 75%               -71.066498   1635.000000   1991.000000      1.000000
# max                 0.000000   2003.000000   2001.000000      2.000000

# %%
dfmarch = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data March.csv')
dfmarch.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count   62985.000000      62985.000000            62985.000000
# mean      888.164214         90.406319               42.358941
# std      5282.585720         58.689924                0.014204
# min        61.000000          1.000000               42.303469
# 25%       353.000000         42.000000               42.350406
# 50%       569.000000         80.000000               42.359912
# 75%       938.000000        130.000000               42.366277
# max    667070.000000        232.000000               42.400877
#
#        start station longitude  end station id  end station latitude  \
# count             62985.000000    62985.000000          62985.000000
# mean                -71.087795       89.905406             42.359000
# std                   0.024668       59.086791              0.014117
# min                 -71.166491        1.000000             42.303469
# 25%                 -71.104412       41.000000             42.350406
# 50%                 -71.091156       78.000000             42.359912
# 75%                 -71.067662      131.000000             42.366277
# max                 -71.006098      228.000000             42.400877
#
#        end station longitude        bikeid    birth year        gender
# count           62985.000000  62985.000000  58429.000000  62985.000000
# mean              -71.087353   1027.863777   1982.782095      1.134238
# std                 0.024718    592.840788     11.308673      0.520078
# min               -71.166491      1.000000   1888.000000      0.000000
# 25%               -71.104412    526.000000   1977.000000      1.000000
# 50%               -71.088220   1007.000000   1986.000000      1.000000
# 75%               -71.066289   1629.000000   1991.000000      1.000000
# max               -71.006098   2004.000000   2001.000000      2.000000

# %%
dfapril= pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data April.csv')
dfapril.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  9.819400e+04      98194.000000            98194.000000
# mean   1.070922e+03         88.524553               42.358088
# std    1.182508e+04         57.984507                0.014344
# min    6.100000e+01          1.000000               42.303469
# 25%    3.650000e+02         45.000000               42.349225
# 50%    6.070000e+02         75.000000               42.358155
# 75%    1.030000e+03        120.000000               42.365908
# max    2.498110e+06        232.000000               42.406302
#
#        start station longitude  end station id  end station latitude  \
# count             98194.000000    98194.000000          98194.000000
# mean                -71.087063       88.194605             42.358102
# std                   0.024607       58.182738              0.014189
# min                 -71.166491        1.000000             42.303469
# 25%                 -71.103945       43.000000             42.349935
# 50%                 -71.089811       75.000000             42.358155
# 75%                 -71.068922      120.000000             42.365673
# max                 -71.006098      232.000000             42.406302
#
#        end station longitude        bikeid    birth year        gender
# count           98194.000000  98194.000000  98194.000000  98194.000000
# mean              -71.086638   1011.586187   1981.781076      1.082256
# std                 0.024613    586.808393     11.668660      0.572404
# min               -71.166491      1.000000   1888.000000      0.000000
# 25%               -71.103945    525.000000   1970.000000      1.000000
# 50%               -71.088220    988.000000   1986.000000      1.000000
# 75%               -71.066289   1576.000000   1991.000000      1.000000
# max               -71.006098   2004.000000   2002.000000      2.000000

# %%
dfmay = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data May.csv')
dfmay.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.788650e+05     178865.000000           178865.000000
# mean   1.562178e+03         88.317245               42.357409
# std    4.329761e+04         58.560581                0.014519
# min    6.100000e+01          1.000000               42.303469
# 25%    4.280000e+02         43.000000               42.348717
# 50%    7.280000e+02         74.000000               42.358100
# 75%    1.207000e+03        124.000000               42.365673
# max    9.328558e+06        232.000000               42.406302
#
#        start station longitude  end station id  end station latitude  \
# count            178865.000000   178865.000000         178865.000000
# mean                -71.085090       88.505633             42.357379
# std                   0.025097       58.894745              0.014505
# min                 -71.166491        1.000000             42.303469
# 25%                 -71.103100       43.000000             42.348717
# 50%                 -71.085954       74.000000             42.357753
# 75%                 -71.064263      125.000000             42.365673
# max                 -71.006098      232.000000             42.406302
#
#        end station longitude        bikeid     birth year         gender
# count          178865.000000  178865.00000  178865.000000  178865.000000
# mean              -71.084767    1875.32903    1981.054818       1.064602
# std                 0.025142     952.57628      11.716032       0.603111
# min               -71.166491       1.00000    1887.000000       0.000000
# 25%               -71.103100    1030.00000    1969.000000       1.000000
# 50%               -71.085824    2108.00000    1984.000000       1.000000
# 75%               -71.064263    2661.00000    1991.000000       1.000000
# max               -71.006098    3306.00000    2002.000000       2.000000

# %%
dfjune = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike
000000               42.406302
#
#        start station longitude  end station id  end station latitude  \
# count             81961.000000    81961.000000          81961.000000
# mean                -71.088940      124.532985             42.358804
# std                   0.024722      101.242602              0.014729
# min                 -71.166491        1.000000             42.167226
# 25%                 -71.104412       46.000000             42.349530
# 50%                 -71.091690       91.000000             42.359573
# 75%                 -71.068922      179.000000             42.366162
# max                 -70.905558      378.000000             42.406302
#
#        end station longitude        bikeid    birth year        gender
# count           81961.000000  81961.000000  81961.000000  81961.000000
# mean              -71.088201   3169.448445   1983.667378      1.161430
# std                 0.024629    869.717602     11.541828      0.504629
# min               -71.166491      5.000000   1888.000000      0.000000
# 25%               -71.104079   2591.000000   1977.000000      1.000000
# 50%               -71.091156   3346.000000   1988.000000      1.000000
# 75%               -71.067705   3857.000000   1992.000000      1.000000
# max               -70.905558   4553.000000   2002.000000      2.000000

# %%
dfnov = dfdec = pd.read_csv(r'C:\Users\harr1\Desktop\Thinkful\Boston Bike Data.csv')
dfdec.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  1.214190e+05     121419.000000           121419.000000
# mean   1.234644e+03        114.707311               42.358157
# std    1.853257e+04         91.828251                0.015366
# min    6.100000e+01          1.000000               42.167226
# 25%    3.650000e+02         51.000000               42.348810
# 50%    5.910000e+02         87.000000               42.358100
# 75%    9.790000e+02        177.000000               42.365994
# max    2.146146e+06        374.000000               42.406302
#
#        start station longitude  end station id  end station latitude  \
# count            121419.000000   121419.000000         121419.000000
# mean                -71.088969      114.345028             42.357839
# std                   0.024568       92.227295              0.122503
# min                 -71.166491        1.000000              0.000000
# 25%                 -71.104412       49.000000             42.348953
# 50%                 -71.091156       84.000000             42.358100
# 75%                 -71.069849      177.000000             42.365908
# max                 -70.905558      376.000000             42.406302
#
#        end station longitude         bikeid     birth year         gender
# count          121419.000000  121419.000000  121419.000000  121419.000000
# mean              -71.087822    3020.227518    1984.443596       1.163426
# std                 0.205472     902.348086      11.406707       0.521871
# min               -71.166491       5.000000    1886.000000       0.000000
# 25%               -71.104412    2472.000000    1978.000000       1.000000
# 50%               -71.091156    3176.000000    1988.000000       1.000000
# 75%               -71.068922    3752.000000    1993.000000       1.000000
# max                 0.000000    4301.000000    2002.000000       2.000000

# %%
dfjan['tripduration'].count()
# Out:
# 40932

# %%
dfjan['tripduration'].count()+dffeb['tripduration'].count()+dfmarch['tripduration'].count()+dfapril['tripduration'].count()+dfmay['tripduration'].count()+dfjune['tripduration'].count()+dfjuly['tripduration'].count()+dfaug['tripduration'].count()+dfsept['tripduration'].count()+dfoct['tripduration'].count()+dfnov['tripduration'].count()+dfdec['tripduration'].count()
# Out:
# 1807264

# %%
Trips_per_month = {
    "January" : dfjan['tripduration'].count(),
    "February" : dffeb['tripduration'].count(),
    "March" : dfmarch['tripduration'].count(),
    "April" : dfapril['tripduration'].count(),
    "May" : dfmay['tripduration'].count(),
    "June" : dfjune['tripduration'].count(),
    "July" : dfjuly['tripduration'].count(),
    "August" : dfaug['tripduration'].count(),
    "September" : dfsept['tripduration'].count(),
    "October" : dfoct['tripduration'].count(),
    "November" : dfnov['tripduration'].count(),
    "December" : dfdec['tripduration'].count(),
}
print (Trips_per_month)
# Out:
# {'January': 40932, 'February': 62817, 'March': 62985, 'April': 98194, 'May': 178865, 'June': 205359, 'July': 242916, 'August': 236076, 'September': 236182, 'October': 200100, 'November': 121419, 'December': 121419}

# %%
#create bar chart using dictionary
plt.bar(range(len(Trips_per_month)), list(Trips_per_month.values()), align='center')
plt.xticks(range(len(Trips_per_month)), list(Trips_per_month.keys()), rotation = 'vertical')
plt.title('Blue Bike trips per month 2018')
plt.ylabel('Number of trips')
plt.show()

# %%
#This is not measuring what you want to show

from scipy.stats import ttest_ind
print(ttest_ind(dfjan['tripduration'], dfjuly['tripduration'], equal_var=False))
print(ttest_ind(dfaug['tripduration'], dfjuly['tripduration'], equal_var=False))#not a significant difference
print(ttest_ind(dfsept['tripduration'], dfjuly['tripduration'], equal_var=False))
# Out:
# Ttest_indResult(statistic=-10.937174583030163, pvalue=7.808182729305212e-28)
# Ttest_indResult(statistic=-0.36080169676808976, pvalue=0.7182478549362548)
# Ttest_indResult(statistic=-5.7625620384973795, pvalue=8.292097561832378e-09)

# %%
Trip_length = {
    "January" : (dfjan['tripduration'].mean())/60,
    "February" : (dffeb['tripduration'].mean())/60,
    "March" : (dfmarch['tripduration'].mean())/60,
    "April" : (dfapril['tripduration'].mean())/60,
    "May" : (dfmay['tripduration'].mean())/60,
    "June" : (dfjune['tripduration'].mean())/60,
    "July" : (dfjuly['tripduration'].mean())/60,
    "August" : (dfaug['tripduration'].mean())/60,
    "September" : (dfsept['tripduration'].mean())/60,
    "October" : (dfoct['tripduration'].mean())/60,
    "November" : (dfnov['tripduration'].mean())/60,
    "December" : (dfdec['tripduration'].mean())/60,
}
print (Trip_length)
# Out:
# {'January': 14.421615524935666, 'February': 16.35644968718659, 'March': 14.802736895027916, 'April': 17.848706472221654, 'May': 26.03630736402687, 'June': 28.700219453087847, 'July': 32.45914829268828, 'August': 31.84345606217207, 'September': 24.50712988288693, 'October': 33.60113326669998, 'November': 20.577400434308743, 'December': 20.577400434308743}

# %%
Trip_max = {
    "January" : ((dfjan['tripduration'].max())/60)/24,
    "February" : ((dffeb['tripduration'].max())/60)/24,
    "March" : ((dfmarch['tripduration'].max())/60)/24,
    "April" : ((dfapril['tripduration'].max())/60)/24,
    "May" : ((dfmay['tripduration'].max())/60)/24,
    "June" : ((dfjune['tripduration'].max())/60)/24,
    "July" : ((dfjuly['tripduration'].max())/60)/24,
    "August" : ((dfaug['tripduration'].max())/60)/24,
    "September" : ((dfsept['tripduration'].max())/60)/24,
    "October" : ((dfoct['tripduration'].max())/60)/24,
    "November" : ((dfnov['tripduration'].max())/60)/24,
    "December" : ((dfdec['tripduration'].max())/60)/24,
}
plt.bar(range(len(Trip_max)), list(Trip_max.values()), align='center')
plt.xticks(range(len(Trip_max)), list(Trip_max.keys()), rotation = 'vertical')
plt.title('Maximum Trip Lengths')
plt.ylabel('Time of trips (hours)')
plt.show()

# %%
#Due to what seems to be a very skewed dataset, I cannot use the trip durations until that data is cleaned.
